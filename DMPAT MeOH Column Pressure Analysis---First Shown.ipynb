# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('datasets\MeOH Section Analysis.csv')
df.head()
# Out:
#        Date and Time  R-14601 PH CONTROL AIC PV  CHW-A Flow  CHW-B Flow  \
# 0  3-9-2022 12:00 AM                  11.349625   75.993752   69.300003
# 1  3-9-2022 12:01 AM                  10.148250   75.862503   69.168747
# 2  3-9-2022 12:02 AM                   6.196749   76.218750   69.525002
# 3  3-9-2022 12:03 AM                   5.688375   76.125000   69.393753
# 4  3-9-2022 12:04 AM                  10.706500   76.218750   69.525002
#
#    PH TRANSMITTER OF T-14601  D-14601 TO R-14601 FLOW PV  \
# 0                  10.616375                         NaN
# 1                  10.651375                         NaN
# 2                  10.700375                         NaN
# 3                  10.717000                         NaN
# 4                  10.688999                         NaN
#
#    C-14601A MEOH FIC REFLUX PV  C-14601A FEED CONTROL FIC PV  \
# 0                  2254.308105                   9601.349609
# 1                  2227.800049                   9589.849609
# ...

# %%
df.drop(['D-14601 TO R-14601 FLOW PV'], axis=1, inplace =True)
df.head()
# Out:
#        Date and Time  R-14601 PH CONTROL AIC PV  CHW-A Flow  CHW-B Flow  \
# 0  3-9-2022 12:00 AM                  11.349625   75.993752   69.300003
# 1  3-9-2022 12:01 AM                  10.148250   75.862503   69.168747
# 2  3-9-2022 12:02 AM                   6.196749   76.218750   69.525002
# 3  3-9-2022 12:03 AM                   5.688375   76.125000   69.393753
# 4  3-9-2022 12:04 AM                  10.706500   76.218750   69.525002
#
#    PH TRANSMITTER OF T-14601  C-14601A MEOH FIC REFLUX PV  \
# 0                  10.616375                  2254.308105
# 1                  10.651375                  2227.800049
# 2                  10.700375                  2221.595947
# 3                  10.717000                  2225.543945
# 4                  10.688999                  2197.907959
#
#    C-14601A FEED CONTROL FIC PV  C-14601 MeOH FD FLOW FIC PV  \
# 0                   9601.349609                  9749.699219
# ...

# %%
df.isnull().sum()
# Out:
# Date and Time                       6
# R-14601 PH CONTROL AIC PV           6
# CHW-A Flow                          6
# CHW-B Flow                          6
# PH TRANSMITTER OF T-14601           6
# C-14601A MEOH FIC REFLUX PV         6
# C-14601A FEED CONTROL FIC PV        6
# C-14601 MeOH FD FLOW FIC PV         6
# C-14601 MeOH CLM REFLUX FIC PV      6
# H14601A_1 STM FIC PV                6
# HE-14601 STM FIC PV                 6
# R-14601 CAUSTIC CONTROL FIC PV      6
# C14601A_01MEOH+AQS LIC PV           6
# C-14601_01 MEOH+AQS OF LIC PV       6
# T-14601 LEVEL CONTROL LIC PV        6
# V14601A reflux Vessel CLM LIC PV    6
# V-14601 MEOH LIC PV                 6
# LT D-14601_1                        6
# C14601A PRES Bottom. PV             6
# C-14601A PRES Top. PV               6
# C-14601 BOTTOM PT                   6
# C-14601A MEOH TIC Bottom PV         6
# C-14601A MEOH TIC TOP PV            6
# C-14601 MeOH CLM BTM TIC PV         6
# C-14601 MeOH CLM TOP TIC PV         6
# ...

# %%
df.tail(10)
# Out:
#           Date and Time  R-14601 PH CONTROL AIC PV  CHW-A Flow  CHW-B Flow  \
# 3861  3-11-2022 4:21 PM                   10.51925   72.881248   73.106247
# 3862  3-11-2022 4:22 PM                    7.60375   72.487503   72.731247
# 3863  3-11-2022 4:23 PM                    5.82225   73.106247   73.406250
# 3864  3-11-2022 4:24 PM                    8.79025   72.899994   73.125000
# 3865                NaN                        NaN         NaN         NaN
# 3866                NaN                        NaN         NaN         NaN
# 3867                NaN                        NaN         NaN         NaN
# 3868                NaN                        NaN         NaN         NaN
# 3869                NaN                        NaN         NaN         NaN
# 3870                NaN                        NaN         NaN         NaN
#
#       PH TRANSMITTER OF T-14601  C-14601A MEOH FIC REFLUX PV  \
# 3861                  10.771251                  2898.396240
# ...

# %%
df.drop([3865,3866,3867,3868,3869,3870], inplace=True)

# %%
df.tail(10)
# Out:
#           Date and Time  R-14601 PH CONTROL AIC PV  CHW-A Flow  CHW-B Flow  \
# 3855  3-11-2022 4:15 PM                  10.247127   72.731247   72.918747
# 3856  3-11-2022 4:16 PM                   6.523125   72.862503   73.049995
# 3857  3-11-2022 4:17 PM                   5.906250   72.356247   72.618752
# 3858  3-11-2022 4:18 PM                  10.317126   72.693748   72.899994
# 3859  3-11-2022 4:19 PM                  11.498375   72.637497   72.843750
# 3860  3-11-2022 4:20 PM                  11.460750   72.524994   72.731247
# 3861  3-11-2022 4:21 PM                  10.519250   72.881248   73.106247
# 3862  3-11-2022 4:22 PM                   7.603750   72.487503   72.731247
# 3863  3-11-2022 4:23 PM                   5.822250   73.106247   73.406250
# 3864  3-11-2022 4:24 PM                   8.790250   72.899994   73.125000
#
#       PH TRANSMITTER OF T-14601  C-14601A MEOH FIC REFLUX PV  \
# 3855                  10.762500                  2830.716064
# ...

# %%
df.isnull().sum()
# Out:
# Date and Time                       0
# R-14601 PH CONTROL AIC PV           0
# CHW-A Flow                          0
# CHW-B Flow                          0
# PH TRANSMITTER OF T-14601           0
# C-14601A MEOH FIC REFLUX PV         0
# C-14601A FEED CONTROL FIC PV        0
# C-14601 MeOH FD FLOW FIC PV         0
# C-14601 MeOH CLM REFLUX FIC PV      0
# H14601A_1 STM FIC PV                0
# HE-14601 STM FIC PV                 0
# R-14601 CAUSTIC CONTROL FIC PV      0
# C14601A_01MEOH+AQS LIC PV           0
# C-14601_01 MEOH+AQS OF LIC PV       0
# T-14601 LEVEL CONTROL LIC PV        0
# V14601A reflux Vessel CLM LIC PV    0
# V-14601 MEOH LIC PV                 0
# LT D-14601_1                        0
# C14601A PRES Bottom. PV             0
# C-14601A PRES Top. PV               0
# C-14601 BOTTOM PT                   0
# C-14601A MEOH TIC Bottom PV         0
# C-14601A MEOH TIC TOP PV            0
# C-14601 MeOH CLM BTM TIC PV         0
# C-14601 MeOH CLM TOP TIC PV         0
# ...

# %%
# df.set_index('Date and Time', inplace =True)
df.reset_index()
# Out:
#           Date and Time  R-14601 PH CONTROL AIC PV  CHW-A Flow  CHW-B Flow  \
# 0     3-9-2022 12:00 AM                  11.349625   75.993752   69.300003
# 1     3-9-2022 12:01 AM                  10.148250   75.862503   69.168747
# 2     3-9-2022 12:02 AM                   6.196749   76.218750   69.525002
# 3     3-9-2022 12:03 AM                   5.688375   76.125000   69.393753
# 4     3-9-2022 12:04 AM                  10.706500   76.218750   69.525002
# ...                 ...                        ...         ...         ...
# 3860  3-11-2022 4:20 PM                  11.460750   72.524994   72.731247
# 3861  3-11-2022 4:21 PM                  10.519250   72.881248   73.106247
# 3862  3-11-2022 4:22 PM                   7.603750   72.487503   72.731247
# 3863  3-11-2022 4:23 PM                   5.822250   73.106247   73.406250
# 3864  3-11-2022 4:24 PM                   8.790250   72.899994   73.125000
#
#       PH TRANSMITTER OF T-14601  C-14601A MEOH FIC REFLUX PV  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3865 entries, 3-9-2022 12:00 AM to 3-11-2022 4:24 PM
# Data columns (total 39 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   R-14601 PH CONTROL AIC PV         3865 non-null   float64
#  1   CHW-A Flow                        3865 non-null   float64
#  2   CHW-B Flow                        3865 non-null   float64
#  3   PH TRANSMITTER OF T-14601         3865 non-null   float64
#  4   C-14601A MEOH FIC REFLUX PV       3865 non-null   float64
#  5   C-14601A FEED CONTROL FIC PV      3865 non-null   float64
#  6   C-14601 MeOH FD FLOW FIC PV       3865 non-null   float64
#  7   C-14601 MeOH CLM REFLUX FIC PV    3865 non-null   float64
#  8   H14601A_1 STM FIC PV              3865 non-null   float64
#  9   HE-14601 STM FIC PV               3865 non-null   float64
#  10  R-14601 CAUSTIC CONTROL FIC PV    3865 non-null   float64
# ...

# %%
df.describe()
# Out:
#        R-14601 PH CONTROL AIC PV   CHW-A Flow   CHW-B Flow  \
# count                3865.000000  3865.000000  3865.000000
# mean                    9.721303    75.637151    70.052509
# std                     2.114903     0.556612     0.554257
# min                     4.323375    72.225006    67.631248
# 25%                     7.786625    75.431244    69.787498
# 50%                    10.914750    75.674995    70.031250
# 75%                    11.403875    75.899994    70.256256
# max                    11.894750    77.906258    73.537498
#
#        PH TRANSMITTER OF T-14601  C-14601A MEOH FIC REFLUX PV  \
# count                3865.000000                  3865.000000
# mean                   10.975007                  2882.226050
# std                     0.432513                   537.299995
# min                     9.506001                  1957.079956
# 25%                    10.744125                  2386.283936
# ...

# %%
df.columns
# Out:
# Index(['R-14601 PH CONTROL AIC PV', 'CHW-A Flow', 'CHW-B Flow',
#        'PH TRANSMITTER OF T-14601', 'C-14601A MEOH FIC REFLUX PV',
#        'C-14601A FEED CONTROL FIC PV', 'C-14601 MeOH FD FLOW FIC PV',
#        'C-14601 MeOH CLM REFLUX FIC PV', 'H14601A_1 STM FIC PV',
#        'HE-14601 STM FIC PV', 'R-14601 CAUSTIC CONTROL FIC PV',
#        'C14601A_01MEOH+AQS LIC PV', 'C-14601_01 MEOH+AQS OF LIC PV',
#        'T-14601 LEVEL CONTROL LIC PV', 'V14601A reflux Vessel CLM LIC PV',
#        'V-14601 MEOH LIC PV', 'LT D-14601_1', 'C14601A PRES Bottom. PV',
#        'C-14601A PRES Top. PV', 'C-14601 BOTTOM PT',
#        'C-14601A MEOH TIC Bottom PV', 'C-14601A MEOH TIC TOP PV',
#        'C-14601 MeOH CLM BTM TIC PV', 'C-14601 MeOH CLM TOP TIC PV',
#        'TT C14601A_3 MEOH TEMP PV', 'TT C14601A_4 MEOH TEMP PV',
#        'TT C14601A_5 MEOH TEMP PV', 'TT C14601A_6 MEOH TEMP PV',
#        'TT C14601_3MeOH CLM TEMP PV', 'TT C14601_4 MeOH TEMP PV',
# ...

# %%
#histogram of each column 
for feature in df.columns:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
## Pearson Corelation using heatmap
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df_corr=df.corr()
df_corr
# Out:
#                                   R-14601 PH CONTROL AIC PV  CHW-A Flow  \
# R-14601 PH CONTROL AIC PV                          1.000000    0.000109
# CHW-A Flow                                         0.000109    1.000000
# CHW-B Flow                                        -0.002505   -0.518751
# PH TRANSMITTER OF T-14601                          0.289708   -0.036334
# D-14601 TO R-14601 FLOW PV                              NaN         NaN
# C-14601A MEOH FIC REFLUX PV                       -0.097689   -0.173906
# C-14601A FEED CONTROL FIC PV                      -0.046860   -0.045616
# C-14601 MeOH FD FLOW FIC PV                        0.003975   -0.078819
# C-14601 MeOH CLM REFLUX FIC PV                    -0.124890   -0.109155
# H14601A_1 STM FIC PV                              -0.136729   -0.166281
# HE-14601 STM FIC PV                               -0.121546   -0.093204
# R-14601 CAUSTIC CONTROL FIC PV                    -0.611412   -0.022698
# ...

# %%
print(list(zip(df1.index,df1.columns)))
# Out:
# [('R-14601 PH CONTROL AIC PV', 'R-14601 PH CONTROL AIC PV'), ('CHW-A Flow', 'CHW-A Flow'), ('CHW-B Flow', 'CHW-B Flow'), ('PH TRANSMITTER OF T-14601', 'PH TRANSMITTER OF T-14601'), ('C-14601A MEOH FIC REFLUX PV', 'C-14601A MEOH FIC REFLUX PV'), ('C-14601A FEED CONTROL FIC PV', 'C-14601A FEED CONTROL FIC PV'), ('C-14601 MeOH FD FLOW FIC PV', 'C-14601 MeOH FD FLOW FIC PV'), ('C-14601 MeOH CLM REFLUX FIC PV', 'C-14601 MeOH CLM REFLUX FIC PV'), ('H14601A_1 STM FIC PV', 'H14601A_1 STM FIC PV'), ('HE-14601 STM FIC PV', 'HE-14601 STM FIC PV'), ('R-14601 CAUSTIC CONTROL FIC PV', 'R-14601 CAUSTIC CONTROL FIC PV'), ('C14601A_01MEOH+AQS LIC PV', 'C14601A_01MEOH+AQS LIC PV'), ('C-14601_01 MEOH+AQS OF LIC PV', 'C-14601_01 MEOH+AQS OF LIC PV'), ('T-14601 LEVEL CONTROL LIC PV', 'T-14601 LEVEL CONTROL LIC PV'), ('V14601A reflux Vessel CLM LIC PV', 'V14601A reflux Vessel CLM LIC PV'), ('V-14601 MEOH LIC PV', 'V-14601 MEOH LIC PV'), ('LT D-14601_1', 'LT D-14601_1'), ('C14601A PRES Bottom. PV', 'C14601
# ...

# %%
# for group, frame in df1.groupby(df.index):
#     print(group, )
a= list(zip(df_corr.index,df_corr.columns))

for x ,y in list(zip(df_corr.index,df_corr.columns)):
    for z,s in a:
        print('The correlation of', x ,'and', s, 'is {:.2f}'.format(df_corr.loc[x,s]))
        continue
# Out:
# The correlation of R-14601 PH CONTROL AIC PV and R-14601 PH CONTROL AIC PV is 1.00
# The correlation of R-14601 PH CONTROL AIC PV and CHW-A Flow is 0.00
# The correlation of R-14601 PH CONTROL AIC PV and CHW-B Flow is -0.00
# The correlation of R-14601 PH CONTROL AIC PV and PH TRANSMITTER OF T-14601 is 0.29
# The correlation of R-14601 PH CONTROL AIC PV and D-14601 TO R-14601 FLOW PV is nan
# The correlation of R-14601 PH CONTROL AIC PV and C-14601A MEOH FIC REFLUX PV is -0.10
# The correlation of R-14601 PH CONTROL AIC PV and C-14601A FEED CONTROL FIC PV is -0.05
# The correlation of R-14601 PH CONTROL AIC PV and C-14601 MeOH FD FLOW FIC PV is 0.00
# The correlation of R-14601 PH CONTROL AIC PV and C-14601 MeOH CLM REFLUX FIC PV is -0.12
# The correlation of R-14601 PH CONTROL AIC PV and H14601A_1 STM FIC PV is -0.14
# The correlation of R-14601 PH CONTROL AIC PV and HE-14601 STM FIC PV is -0.12
# ...

# %%
df.shape
# Out:
# (3865, 39)

# %%
# # # plt.plot(df['Date and Time'], df['C-14601A MEOH FIC REFLUX PV'])
# # # plt.show()
# # df['C-14601A MEOH FIC REFLUX PV'].plot();


# df['C-14601A MEOH FIC REFLUX PV'].plot();
# df['C14601A PRES Bottom. PV'].plot();

# # plt.title("throughput")
# # plt.xlabel("time")
# # plt.ylabel("mbps")
# # plt.legend()
# # plt.xticks(rotation=45)

# %%
df.head()
# Out:
#                    R-14601 PH CONTROL AIC PV  CHW-A Flow  CHW-B Flow  \
# Date and Time
# 3-9-2022 12:00 AM                  11.349625   75.993752   69.300003
# 3-9-2022 12:01 AM                  10.148250   75.862503   69.168747
# 3-9-2022 12:02 AM                   6.196749   76.218750   69.525002
# 3-9-2022 12:03 AM                   5.688375   76.125000   69.393753
# 3-9-2022 12:04 AM                  10.706500   76.218750   69.525002
#
#                    PH TRANSMITTER OF T-14601  D-14601 TO R-14601 FLOW PV  \
# Date and Time
# 3-9-2022 12:00 AM                  10.616375                         NaN
# 3-9-2022 12:01 AM                  10.651375                         NaN
# 3-9-2022 12:02 AM                  10.700375                         NaN
# 3-9-2022 12:03 AM                  10.717000                         NaN
# 3-9-2022 12:04 AM                  10.688999                         NaN
#
#                    C-14601A MEOH FIC REFLUX PV  C-14601A FEED CONTROL FIC PV  \
# ...

# %%
## cutting short the df to analyse

df1=df[['C-14601A MEOH FIC REFLUX PV', 'C14601A PRES Bottom. PV']]

clf1= df1.values

# transforming features to analyse better 
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
clf1_scaled = scaler.fit_transform(clf1)
df1_scaled= pd.DataFrame(clf1_scaled)

#converting names
df1_scaled.columns=['C-14601A MEOH FIC REFLUX PV', 'C14601A PRES Bottom. PV']
df1_scaled.index=df.index

df1_scaled.head()
# Out:
#                    C-14601A MEOH FIC REFLUX PV  C14601A PRES Bottom. PV
# Date and Time
# 3-9-2022 12:00 AM                     0.124498                 0.569778
# 3-9-2022 12:01 AM                     0.113395                 0.561922
# 3-9-2022 12:02 AM                     0.110796                 0.543900
# 3-9-2022 12:03 AM                     0.112450                 0.539741
# 3-9-2022 12:04 AM                     0.100874                 0.530499

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df1_scaled['C-14601A MEOH FIC REFLUX PV'].plot(label='C14601A Reflux', color='orange')
df1_scaled['C14601A PRES Bottom. PV'].plot(label='C14601A Bottom Pressure')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df2=df[['C14601A PRES Bottom. PV','PH TRANSMITTER OF T-14601']]

clf2= df2.values

# transforming features to analyse better 
clf2_scaled = scaler.fit_transform(clf2)
df2_scaled= pd.DataFrame(clf2_scaled)

#converting names
df2_scaled.columns=['C14601A PRES Bottom. PV','PH TRANSMITTER OF T-14601']
df2_scaled.index=df.index

df2_scaled.head()
# Out:
#                    C14601A PRES Bottom. PV  PH TRANSMITTER OF T-14601
# Date and Time
# 3-9-2022 12:00 AM                 0.569778                   0.466201
# 3-9-2022 12:01 AM                 0.561922                   0.480896
# 3-9-2022 12:02 AM                 0.543900                   0.501469
# 3-9-2022 12:03 AM                 0.539741                   0.508449
# 3-9-2022 12:04 AM                 0.530499                   0.496693

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df2_scaled['C14601A PRES Bottom. PV'].plot(label='C14601A Bottom Pressure', color='orange')
df2_scaled['PH TRANSMITTER OF T-14601'].plot(label='PH TRANSMITTER OF T-14601')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df3=df[['C14601A PRES Bottom. PV','H14601A_1 STM FIC PV']]

clf3= df3.values

# transforming features to analyse better 
clf3_scaled = scaler.fit_transform(clf3)
df3_scaled= pd.DataFrame(clf3_scaled)

#converting names
df3_scaled.columns=['C14601A PRES Bottom. PV','H14601A_1 STM FIC PV']
df3_scaled.index=df.index

df3_scaled.head()
# Out:
#                    C14601A PRES Bottom. PV  H14601A_1 STM FIC PV
# Date and Time
# 3-9-2022 12:00 AM                 0.569778              0.280528
# 3-9-2022 12:01 AM                 0.561922              0.278642
# 3-9-2022 12:02 AM                 0.543900              0.277699
# 3-9-2022 12:03 AM                 0.539741              0.276285
# 3-9-2022 12:04 AM                 0.530499              0.281000

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df3_scaled['C14601A PRES Bottom. PV'].plot(label='C14601A Bottom Pressure', color='orange')
df3_scaled['H14601A_1 STM FIC PV'].plot(label='Steam Flow to H14601_A')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df4=df[['C-14601A PRES Top. PV','C-14601A MEOH FIC REFLUX PV']]

clf4= df4.values

# transforming features to analyse better 
clf4_scaled = scaler.fit_transform(clf4)
df4_scaled= pd.DataFrame(clf4_scaled)

#converting names
df4_scaled.columns=['C-14601A PRES Top. PV','C-14601A MEOH FIC REFLUX PV']
df4_scaled.index=df.index

df4_scaled.head()
# Out:
#                    C-14601A PRES Top. PV  C-14601A MEOH FIC REFLUX PV
# Date and Time
# 3-9-2022 12:00 AM               0.363636                     0.124498
# 3-9-2022 12:01 AM               0.272727                     0.113395
# 3-9-2022 12:02 AM               0.272727                     0.110796
# 3-9-2022 12:03 AM               0.318182                     0.112450
# 3-9-2022 12:04 AM               0.318182                     0.100874

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df4_scaled['C-14601A PRES Top. PV'].plot(label='C-14601A Top Pressure', color='orange')
df4_scaled['C-14601A MEOH FIC REFLUX PV'].plot(label='C14601_A Reflux Flow')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df5=df[['C-14601A PRES Top. PV','H14601A_1 STM FIC PV']]

clf5= df5.values

# transforming features to analyse better 
clf5_scaled = scaler.fit_transform(clf5)
df5_scaled= pd.DataFrame(clf5_scaled)

#converting names
df5_scaled.columns=['C-14601A PRES Top. PV','H14601A_1 STM FIC PV']
df5_scaled.index=df.index

df5_scaled.head()
# Out:
#                    C-14601A PRES Top. PV  H14601A_1 STM FIC PV
# Date and Time
# 3-9-2022 12:00 AM               0.363636              0.280528
# 3-9-2022 12:01 AM               0.272727              0.278642
# 3-9-2022 12:02 AM               0.272727              0.277699
# 3-9-2022 12:03 AM               0.318182              0.276285
# 3-9-2022 12:04 AM               0.318182              0.281000

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df5_scaled['C-14601A PRES Top. PV'].plot(label='C-14601A Top Pressure', color='orange')
df5_scaled['H14601A_1 STM FIC PV'].plot(label='Steam flow to H14601_A')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df6=df[['C-14601A PRES Top. PV', 'C14601A PRES Bottom. PV']]

clf6= df6.values

# transforming features to analyse better 
clf6_scaled = scaler.fit_transform(clf6)
df6_scaled= pd.DataFrame(clf6_scaled)

#converting names
df6_scaled.columns=['C-14601A PRES Top. PV', 'C14601A PRES Bottom. PV']
df6_scaled.index=df.index

df6_scaled.head()
# Out:
#                    C-14601A PRES Top. PV  C14601A PRES Bottom. PV
# Date and Time
# 3-9-2022 12:00 AM               0.363636                 0.569778
# 3-9-2022 12:01 AM               0.272727                 0.561922
# 3-9-2022 12:02 AM               0.272727                 0.543900
# 3-9-2022 12:03 AM               0.318182                 0.539741
# 3-9-2022 12:04 AM               0.318182                 0.530499

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df6_scaled['C-14601A PRES Top. PV'].plot(label='C-14601A Top Pressure', color='orange')
df6_scaled['C14601A PRES Bottom. PV'].plot(label='C-14601A bottom Pressure')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df7=df[['C-14601A PRES Top. PV','TT C14601A_3 MEOH TEMP PV']]

clf7= df7.values

# transforming features to analyse better 
clf7_scaled = scaler.fit_transform(clf7)
df7_scaled= pd.DataFrame(clf7_scaled)

#converting names
df7_scaled.columns=['C-14601A PRES Top. PV','TT C14601A_3 MEOH TEMP PV']
df7_scaled.index=df.index

df7_scaled.head()
# Out:
#                    C-14601A PRES Top. PV  TT C14601A_3 MEOH TEMP PV
# Date and Time
# 3-9-2022 12:00 AM               0.363636                   0.129596
# 3-9-2022 12:01 AM               0.272727                   0.124081
# 3-9-2022 12:02 AM               0.272727                   0.121324
# 3-9-2022 12:03 AM               0.318182                   0.117188
# 3-9-2022 12:04 AM               0.318182                   0.111673

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df7_scaled['C-14601A PRES Top. PV'].plot(label='C-14601A Top Pressure', color='orange')
df7_scaled['TT C14601A_3 MEOH TEMP PV'].plot(label='C14601_A_3 temp indication')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()

# %%
## cutting short the df to analyse

df8=df[['C-14601 BOTTOM PT' ,'PH TRANSMITTER OF T-14601']]

clf8= df8.values

# transforming features to analyse better 
clf8_scaled = scaler.fit_transform(clf8)
df8_scaled= pd.DataFrame(clf8_scaled)

#converting names
df8_scaled.columns=['C-14601 BOTTOM PT' ,'PH TRANSMITTER OF T-14601']
df8_scaled.index=df.index

df8_scaled.head()
# Out:
#                    C-14601 BOTTOM PT  PH TRANSMITTER OF T-14601
# Date and Time
# 3-9-2022 12:00 AM           0.490850                   0.466201
# 3-9-2022 12:01 AM           0.497309                   0.480896
# 3-9-2022 12:02 AM           0.495156                   0.501469
# 3-9-2022 12:03 AM           0.509688                   0.508449
# 3-9-2022 12:04 AM           0.512917                   0.496693

# %%
plt.figure(figsize=(16, 8), dpi=150)
  

df8_scaled['C-14601 BOTTOM PT'].plot(label='C-14601 bottom Pressure', color='orange')
df8_scaled['PH TRANSMITTER OF T-14601'].plot(label='PH Transmitter of T14601')
plt.title('Comparison Plot')
  
# adding Label to the x-axis
plt.xlabel('Date and Time')

plt.grid()
  
# adding legend to the curve
plt.legend()
